# %% [markdown]
# # UKRI Funding and University League Score data cleaning
#
# This notebook reads the required data from the UKRI's and Complete University Guide's websites then cleans and formats it into a dataframe for later use my machine learning models.
#
# - The university league tables are well formatted and able to be phrased with BeautifulSoup fairly easily.
# - The UKRI grants data was a bit harder...with each month stored separately with different encodings, inconsistent names and a lack of uniformity in the format of the data.

# %%
import pandas as pd
import requests
import urllib.request
import regex as re
from bs4 import BeautifulSoup

# %% [markdown]
# ## University League data 2022
# The university league table data could be directly pulled from "www.thecompleteuniversityguide.co.uk" using BeautifulSoup. The table is stored as a series of single column lists (all called "col_one") so it was not possible to load the table directly, instead the individual values could be pulled out using bs.find_all with the appropriate filters.

# %%
uni_ranking_page = requests.get('https://www.thecompleteuniversityguide.co.uk/league-tables/rankings?tabletype=full-table')

# %%
soup = BeautifulSoup(uni_ranking_page.content, 'html.parser')

# %%
institute_names = []
for name in soup.find_all("a", {"class" : "uni_lnk"}):
    institute_names.append(name["data-ga-label"])

# %%
institute_scores = []
for item in soup.find_all("div", {"class" : "segtxt"}):
    institute_scores.append(item.findChildren()[0].text)

# %%
col_titles = []
for item in soup.find_all("span", {"class" : "hdrtbl"}):
    col_titles.append(item.text)

# %%
institute_scores_df = pd.DataFrame(data=np.reshape(institute_scores, (130,11), order='F'), 
                                   index=institute_names, 
                                   columns=col_titles)

# %%
institute_scores_df = institute_scores_df.apply(pd.to_numeric, errors='coerce') #convert strings to floats and replace "n/a" with NaN's

# %%
institute_scores_df
# Out:
#                                                     Overall score  \
# University of Oxford                                         1000
# University of Cambridge                                       989
# London School of Economics and Political Scienc...            963
# University of St Andrews                                      947
# Imperial College London                                       895
# ...                                                           ...
# University of Suffolk                                         395
# University of East London                                     374
# Glyndwr University, Wrexham                                   364
# Ravensbourne University London                                333
# University of Bedfordshire                                    304
#
#                                                     Entry standards  \
# University of Oxford                                            200
# University of Cambridge                                         205
# London School of Economics and Political Scienc...              177
# University of St Andrews                                        208
# Imperial College London                                         194
# ...                                                             ...
# University of Suffolk                                           110
# University of East London                                        97
# Glyndwr University, Wrexham                                     102
# Ravensbourne University London                                  113
# University of Bedfordshire                                      103
#
#                                                     Student satisfaction  \
# University of Oxford                                                 NaN
# University of Cambridge                                              NaN
# London School of Economics and Political Scienc...                  3.98
# University of St Andrews                                            4.30
# Imperial College London                                             3.99
# ...                                                                  ...
# University of Suffolk                                               3.96
# University of East London                                           4.00
# Glyndwr University, Wrexham                                         4.14
# Ravensbourne University London                                      3.80
# University of Bedfordshire                                          3.93
#
#                                                     Research quality  \
# University of Oxford                                            3.34
# University of Cambridge                                         3.33
# London School of Economics and Political Scienc...              3.35
# University of St Andrews                                        3.13
# Imperial College London                                         3.36
# ...                                                              ...
# University of Suffolk                                            NaN
# University of East London                                       2.71
# Glyndwr University, Wrexham                                     2.15
# Ravensbourne University London                                   NaN
# University of Bedfordshire                                      2.52
#
#                                                     Research intensity  \
# University of Oxford                                              0.87
# University of Cambridge                                           0.95
# London School of Economics and Political Scienc...                0.85
# University of St Andrews                                          0.82
# Imperial College London                                           0.92
# ...                                                                ...
# University of Suffolk                                              NaN
# University of East London                                         0.23
# Glyndwr University, Wrexham                                       0.16
# Ravensbourne University London                                     NaN
# University of Bedfordshire                                        0.27
#
#                                                     Academic services spend  \
# University of Oxford                                                   2842
# University of Cambridge                                                2718
# London School of Economics and Political Scienc...                     2051
# University of St Andrews                                               2650
# Imperial College London                                                2982
# ...                                                                     ...
# University of Suffolk                                                  1961
# University of East London                                              1105
# Glyndwr University, Wrexham                                            1334
# Ravensbourne University London                                         1163
# University of Bedfordshire                                             1750
#
#                                                     Facilities spend  \
# University of Oxford                                             599
# University of Cambridge                                         1043
# London School of Economics and Political Scienc...               853
# University of St Andrews                                         746
# Imperial College London                                          755
# ...                                                              ...
# University of Suffolk                                            478
# University of East London                                        756
# Glyndwr University, Wrexham                                      559
# Ravensbourne University London                                   322
# University of Bedfordshire                                       673
#
#                                                     Degree completion  \
# University of Oxford                                             99.1
# University of Cambridge                                          99.1
# London School of Economics and Political Scienc...               96.5
# University of St Andrews                                         95.7
# Imperial College London                                          97.5
# ...                                                               ...
# University of Suffolk                                            65.0
# University of East London                                        76.5
# Glyndwr University, Wrexham                                      73.3
# Ravensbourne University London                                   79.7
# University of Bedfordshire                                       53.1
#
#                                                     Student -staff ratio  \
# University of Oxford                                                10.1
# University of Cambridge                                             11.4
# London School of Economics and Political Scienc...                  12.4
# University of St Andrews                                            11.1
# Imperial College London                                             11.1
# ...                                                                  ...
# University of Suffolk                                               16.5
# University of East London                                           21.9
# Glyndwr University, Wrexham                                         21.9
# Ravensbourne University London                                      22.6
# University of Bedfordshire                                          23.5
#
#                                                     Graduate prospects – outcomes  \
# University of Oxford                                                         90.4
# University of Cambridge                                                      90.0
# London School of Economics and Political Scienc...                           90.6
# University of St Andrews                                                     79.9
# Imperial College London                                                      95.1
# ...                                                                           ...
# University of Suffolk                                                        74.4
# University of East London                                                    56.5
# Glyndwr University, Wrexham                                                  62.9
# Ravensbourne University London                                               70.0
# University of Bedfordshire                                                   66.2
#
#                                                     Graduate prospects – on track
# University of Oxford                                                         84.7
# University of Cambridge                                                      86.0
# London School of Economics and Political Scienc...                           83.3
# University of St Andrews                                                     79.6
# Imperial College London                                                      86.7
# ...                                                                           ...
# University of Suffolk                                                        80.9
# University of East London                                                    69.6
# Glyndwr University, Wrexham                                                  68.6
# Ravensbourne University London                                               77.5
# University of Bedfordshire                                                   73.1
#
# [130 rows x 11 columns]

# %% [markdown]
# ## UK Research and Innovate (UKRI) funding data for the years 2018-2020
# - UKRI is a new project that consolidates a large number of separate funding bodies so there is no aggregated data pre 2018.

# %%
UKRI_URL = 'https://www.ukri.org/about-us/what-we-do/financial-data/'
UKRI_HTML = requests.get(url = UKRI_URL).text

# %%
def download_UKRI_expenditure(HTML, download_signature):
    """
    Function to import the csv file names from an HTML page, given a REGEX identifier
        
    Returns a dict with pd.DataFrames for each csv with the REGEX identifier.       
    """
    data_URL_set = re.findall(download_signature, HTML)
    data = {}
    for url in data_URL_set:
        with urllib.request.urlopen('https://www.ukri.org/'+url) as html_doc:
            data[url] = pd.read_csv(html_doc,
                                    encoding='cp1252', 
                                    dtype=str,
                                    low_memory=False)
    return(data)

# %% [markdown]
# The csv's were in a poor shape with a non-uniform set of columns/column names, some with Byte Order Marks, some without as well as trailing white space in some instances. Beautiful soup could be used, but regex was chosen as an easier way to select just the expenditure data.
#
# - utf-8-sig decoding could not be used to remove the byte order mark as there were non utf characters in the dataset which causes errors so a manual replacement was used.

# %%
data_dict = download_UKRI_expenditure(UKRI_HTML, '\/wp-content\/uploads\/20\d+\/\d+\/UKRI-\d+-\D+\d+-AllExpenditure.csv')

# %%
for df in data_dict:
    data_dict[df].columns = data_dict[df].columns.str.replace('ï»¿', '') #removes byte order mark
    data_dict[df].columns = data_dict[df].columns.str.strip()

# %%
UKRI_spending = pd.concat(data_dict.values())
UKRI_spending.dropna(how='all', axis=1, inplace=True) #remove blank columns
UKRI_spending.head()
# Out:
#   Department Family       Entity        Date  \
# 0              BEIS  UKRI - AHRC  02/12/2020
# 1              BEIS  UKRI - AHRC  02/12/2020
# 2              BEIS  UKRI - AHRC  02/12/2020
# 3              BEIS  UKRI - AHRC  02/12/2020
# 4              BEIS  UKRI - AHRC  02/12/2020
#
#                        Expense Type               Expense Area  \
# 0  Fees (Including College Members)  GCRF - Programme Delivery
# 1  Fees (Including College Members)  GCRF - Programme Delivery
# 2  Fees (Including College Members)         Cultural Value EDI
# 3  Fees (Including College Members)  GCRF - Programme Delivery
# 4  Fees (Including College Members)           Executive Office
#
#                          Supplier Transaction Number  Amount  \
# 0  Non Employee Expenses Supplier           98856194  170.00
# 1  Non Employee Expenses Supplier           98856195  170.00
# 2  Non Employee Expenses Supplier           98856196  340.00
# 3  Non Employee Expenses Supplier           98856197  170.00
# 4  Non Employee Expenses Supplier           98856198  500.00
#
#                    Item Description Unnamed: 11
# 0  Fees (Including College Members)         NaN
# 1  Fees (Including College Members)         NaN
# 2  Fees (Including College Members)         NaN
# 3  Fees (Including College Members)         NaN
# 4  Fees (Including College Members)         NaN

# %%
UKRI_spending[UKRI_spending["Unnamed: 11"].isnull()==False]
# Out:
#       Department Family              Entity        Date   Expense Type  \
# 50640              BEIS  UKRI - Innovate UK  01/01/2020  Assessor Fees
#
#          Expense Area        Supplier Transaction Number    Amount  \
# 50640  Healthy Ageing  CATON BELL LTD              60895  1,710.00
#
#       Item Description                                        Unnamed: 11
# 50640    Assessor Fees                                                ...

# %%
UKRI_spending.drop(["Unnamed: 11"], axis=1, inplace=True) #only has one entry

# %%
UKRI_spending.head()
# Out:
#   Department Family       Entity        Date  \
# 0              BEIS  UKRI - AHRC  02/12/2020
# 1              BEIS  UKRI - AHRC  02/12/2020
# 2              BEIS  UKRI - AHRC  02/12/2020
# 3              BEIS  UKRI - AHRC  02/12/2020
# 4              BEIS  UKRI - AHRC  02/12/2020
#
#                        Expense Type               Expense Area  \
# 0  Fees (Including College Members)  GCRF - Programme Delivery
# 1  Fees (Including College Members)  GCRF - Programme Delivery
# 2  Fees (Including College Members)         Cultural Value EDI
# 3  Fees (Including College Members)  GCRF - Programme Delivery
# 4  Fees (Including College Members)           Executive Office
#
#                          Supplier Transaction Number  Amount  \
# 0  Non Employee Expenses Supplier           98856194  170.00
# 1  Non Employee Expenses Supplier           98856195  170.00
# 2  Non Employee Expenses Supplier           98856196  340.00
# 3  Non Employee Expenses Supplier           98856197  170.00
# 4  Non Employee Expenses Supplier           98856198  500.00
#
#                    Item Description
# 0  Fees (Including College Members)
# 1  Fees (Including College Members)
# 2  Fees (Including College Members)
# 3  Fees (Including College Members)
# 4  Fees (Including College Members)

# %%
UKRI_spending.isna().sum()
# Out:
# Department Family     269654
# Entity                269654
# Date                  269663
# Expense Type          270457
# Expense Area          273204
# Supplier              269655
# Transaction Number    269654
# Amount                269654
# Item Description      270455
# dtype: int64

# %%
UKRI_spending.dropna(how="all", inplace=True)
UKRI_spending.isna().sum()
# Out:
# Department Family        0
# Entity                   0
# Date                     9
# Expense Type           803
# Expense Area          3550
# Supplier                 1
# Transaction Number       0
# Amount                   0
# Item Description       801
# dtype: int64

# %% [markdown]
# ### Enough entries that we can drop the remaining NaN's

# %%
UKRI_spending.dropna(inplace=True)

# %%
UKRI_spending.head()
# Out:
#   Department Family       Entity        Date  \
# 0              BEIS  UKRI - AHRC  02/12/2020
# 1              BEIS  UKRI - AHRC  02/12/2020
# 2              BEIS  UKRI - AHRC  02/12/2020
# 3              BEIS  UKRI - AHRC  02/12/2020
# 4              BEIS  UKRI - AHRC  02/12/2020
#
#                        Expense Type               Expense Area  \
# 0  Fees (Including College Members)  GCRF - Programme Delivery
# 1  Fees (Including College Members)  GCRF - Programme Delivery
# 2  Fees (Including College Members)         Cultural Value EDI
# 3  Fees (Including College Members)  GCRF - Programme Delivery
# 4  Fees (Including College Members)           Executive Office
#
#                          Supplier Transaction Number  Amount  \
# 0  Non Employee Expenses Supplier           98856194  170.00
# 1  Non Employee Expenses Supplier           98856195  170.00
# 2  Non Employee Expenses Supplier           98856196  340.00
# 3  Non Employee Expenses Supplier           98856197  170.00
# 4  Non Employee Expenses Supplier           98856198  500.00
#
#                    Item Description
# 0  Fees (Including College Members)
# 1  Fees (Including College Members)
# 2  Fees (Including College Members)
# 3  Fees (Including College Members)
# 4  Fees (Including College Members)

# %%
UKRI_spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1576642 entries, 0 to 53771
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Department Family   1576642 non-null  object
#  1   Entity              1576642 non-null  object
#  2   Date                1576642 non-null  object
#  3   Expense Type        1576642 non-null  object
#  4   Expense Area        1576642 non-null  object
#  5   Supplier            1576642 non-null  object
#  6   Transaction Number  1576642 non-null  object
#  7   Amount              1576642 non-null  object
#  8   Item Description    1576642 non-null  object
# dtypes: object(9)
# memory usage: 120.3+ MB

# %%
UKRI_spending.describe().transpose()
# Out:
#                       count  unique                        top     freq
# Department Family   1576642       1                       BEIS  1576642
# Entity              1576642      16                UKRI - STFC   400559
# Date                1576642     905                 20/06/2018     9296
# Expense Type        1576642     760  T&S UK - Public Transport   181866
# Expense Area        1576642    3106                Unspecified   110315
# Supplier            1576642   21752                Unspecified   196629
# Transaction Number  1576642  665062                   98357351     3799
# Amount              1576642  304572                       2.50    32680
# Item Description    1576642    1504  T&S UK - Public Transport   175407

# %% [markdown]
# ### Fixing the dtypes of the different collumns as the import is string only. Involves removing some formatting.

# %%
UKRI_spending["Date"] = UKRI_spending["Date"].astype('datetime64')
UKRI_spending["Amount"] = UKRI_spending["Amount"].str.replace(",","", regex=False)
UKRI_spending["Amount"] = UKRI_spending["Amount"].str.replace("(","", regex=False)
UKRI_spending["Amount"] = UKRI_spending["Amount"].str.replace(")","", regex=False).astype(float)

# %% [markdown]
# ### Only the research grant expenditure of expnse type will be used as other types are too vague

# %%
UKRI_spending['Expense Type'].value_counts().head(10)
# Out:
# T&S UK - Public Transport            181866
# Chemicals                            166449
# Research Grant Expenditure           103637
# Research Consumables                  67633
# T&S UK - Accommodation                64939
# Mobile Phone Costs                    55769
# Projects CIP                          49364
# T&S UK - Subsistence                  47347
# Purchase of non capital equipment     43791
# Resource grants                       43456
# Name: Expense Type, dtype: int64

# %%
UKRI_spending = UKRI_spending[UKRI_spending['Expense Type'] == 'Research Grant Expenditure']

# %% [markdown]
# ### removing GRANT and (GRANT) from institute names as they are the same suppliers

# %%
UKRI_spending['Supplier'] = UKRI_spending['Supplier'].str.replace(" GRANT","", regex=False)
UKRI_spending['Supplier'] = UKRI_spending['Supplier'].str.replace(" (GRANT)","", regex=False)
